# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # City Elevation Map for Bike Ride-ability
#
# ## 1. Database Source
#
#
#
# ## 2. Pipeline Structure
#
#
#
# ## 3. Data Transformation
#
#
#
# ## 4.

# %%
import json


with open('data/Austin/austin_texas_osm_line.geojson') as f:
    data = json.load(f)

# %%
geometry = {'geometry':[]}
for i, feature in enumerate(data['features']):
    geometry['geometry'].append({'type':feature['geometry']['type'], 'coordinates':feature['geometry']['coordinates']})

    if i == 50:
        break

# %%
with open('austin.json', 'w') as f:
    json.dump(geometry, f)

# %%
with open('smdata', 'w') as f:
    json.dump(data, f)
#     geo = json.load(f)
# print(geo.keys())
# geo2 = json.loads(str(geo))

# %%
print(len(geo['features']))
# Out:
# 79208

# %%
import pygeoj

testfile = pygeoj.load(filepath="newfile.geojson")
# testfile = pygeoj.load(filepath="data/Austin/austin_texas_osm_line.geojson")

# %%
import pygeoj

# file = pygeoj.load(filepath="data/Austin/austin_texas_osm_point.geojson")
import json


with open('data/Austin/austin_texas_osm_point.geojson', encoding='utf8') as f:
    data = json.load(f)

# %%
features = []
coords = []
for i, feature in enumerate(data['features']):
   features.append({'type':feature['geometry']['type'], 'coordinates':feature['geometry']['coordinates']})
   if i == 5:
        break

for i in features:
    i['coordinates'][0], i['coordinates'][1] = i['coordinates'][1], i['coordinates'][0]
    coords.append(i['coordinates'])
# print(coords)
 
cs = []
for i, feature in enumerate(data['features']):
    coord = data['features'][0]['geometry']['coordinates']
    coord[0], coord[1] = coord[1], coord[0]
    cs.append(coord)
# print(cs)

stuff = []
for feature in data['features']:
    coord = feature['geometry']['coordinates']
    if coord[0] < 0:
        coord[0], coord[1] = coord[1], coord[0]
    stuff.append(coord)
    

import pandas as pd

df = pd.DataFrame(stuff, columns = ['lat', 'lon'])
print(df)
# Out:
#               lat        lon
# 0       29.931036 -98.205962
# 1       29.932035 -98.205980
# 2       29.932205 -98.200477
# 3       29.931934 -98.199112
# 4       29.931662 -98.197739
# 5       29.933107 -98.206014
# 6       29.933216 -98.205848
# 7       29.933164 -98.205555
# 8       29.933225 -98.205478
# 9       29.933427 -98.205805
# 10      29.932860 -98.203990
# 11      29.932566 -98.202432
# 12      29.931269 -98.195649
# 13      29.931298 -98.171476
# 14      29.931534 -98.170716
# 15      29.932302 -98.169513
# 16      29.932989 -98.168443
# 17      29.933025 -98.167105
# 18      29.933337 -98.165993
# 19      29.933574 -98.164277
# 20      29.933798 -98.162679
# 21      29.934127 -98.160457
# 22      29.934054 -98.158966
# 23      29.933996 -98.157386
# 24      29.933953 -98.156426
# 25      29.934242 -98.154832
# 26      29.934518 -98.153265
# 27      29.934809 -98.151609
# 28      29.935088 -98.150009
# 29      29.935358 -98.148449
# ...           ...        ...
# ...

# %%
newfile = pygeoj.new()
import pandas as pd

# Should look like lat=[30.29, 30.20, 30.29],
#                  lon=[-97.70, -97.74, -97.78],
coords = []
#print(newfile[0])
for i, feature in enumerate(testfile):
    newfile.add_feature(feature.properties)
    for j in feature.geometry.coordinates[0]:
        j[0], j[1] = j[1], j[0]
        coords.append(j)
    if i == 5:
        break

df = pd.DataFrame(coords, columns = ['lat', 'lon'])
# df = df[['lon','lat']]
# from random import randint
# df.insert(1, ['elevation'], randint(0, 9))
print(df)
# Out:
#           lat        lon
# 0   29.932587 -98.206097
# 1   29.933632 -98.206097
# 2   29.933718 -98.205933
# 3   29.933718 -98.205539
# 4   29.933667 -98.205478
# 5   29.933225 -98.205478
# 6   29.932587 -98.205478
# 7   29.932587 -98.206097
# 8   29.933332 -98.205575
# 9   29.933398 -98.205559
# 10  29.933385 -98.205484
# 11  29.933318 -98.205500
# 12  29.933332 -98.205575
# 13  29.953786 -98.181692
# 14  29.953830 -98.181688
# 15  29.953828 -98.181649
# 16  29.953785 -98.181649
# 17  29.953786 -98.181692
# 18  29.953819 -98.180937
# 19  29.953826 -98.180935
# 20  29.953832 -98.180930
# 21  29.953837 -98.180924
# 22  29.953839 -98.180916
# 23  29.953840 -98.180908
# 24  29.953837 -98.180899
# 25  29.953833 -98.180892
# 26  29.953827 -98.180886
# 27  29.953819 -98.180884
# 28  29.953811 -98.180885
# 29  29.953804 -98.180889
# 30  29.953798 -98.180895
# 31  29.953795 -98.180903
# 32  29.953794 -98.180912
# 33  29.953795 -98.180920
# 34  29.953799 -98.180927
# 35  29.953805 -98.180933
# ...

# %%
from bokeh.io import show, output_file, output_notebook
from bokeh.models import(GMapPlot, GMapOptions, ColumnDataSource,
                        Circle, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool, )

# %%
# df = df.groupby('index')
map_options = GMapOptions(lat=30.29, lng=-97.73,
                         map_type='roadmap', zoom=7)
api_key = ''

# %%
plot = GMapPlot(x_range=DataRange1d(),
                y_range=DataRange1d(),
                map_options=map_options)
plot.title.text = "Austin"
plot.api_key=api_key
plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())

# %%
baseline = 0
scale = 5

from decimal import *
latList = df['lat'].tolist()
lonList = df['lon'].tolist()
source = ColumnDataSource(
    data=dict(
        lat = [float(Decimal("%.6f" % e)) for e in latList], #df['lat'].tolist(),
        lon = [float(Decimal("%.6f" % e)) for e in lonList], # df['lon'].tolist(),
        #rad = [(i-baseline) / scale for i in df.index.tolist()]
    )
)

# source = ColumnDataSource(
#     data=dict(
#         lat=[30.29, 30.20, 30.29],
#         lon=[-97.70, -97.74, -97.78],
#     )
# )

# %%
#df = df['lat'].round(5)
from decimal import *
latlist = df['lat'].tolist()
lat = [float(Decimal("%.6f" % e)) for e in latlist]
print(lat)

lonlist = df['lon'].tolist()
lon = [float(Decimal("%.6f" % e)) for e in lonlist]
print(lon)
# print([decimal(x) for x in mylist])
# Out:
# [29.932587, 29.933632, 29.933718, 29.933718, 29.933667, 29.933225, 29.932587, 29.932587, 29.933332, 29.933398, 29.933385, 29.933318, 29.933332, 29.953786, 29.95383, 29.953828, 29.953785, 29.953786, 29.953819, 29.953826, 29.953832, 29.953837, 29.953839, 29.95384, 29.953837, 29.953833, 29.953827, 29.953819, 29.953811, 29.953804, 29.953798, 29.953795, 29.953794, 29.953795, 29.953799, 29.953805, 29.953811, 29.953819, 29.955334, 29.955441, 29.955362, 29.95526, 29.955334, 29.955594, 29.955641, 29.955543, 29.955499, 29.955594]
# ...

# %%
circle = Circle(x='lon', y='lat',size=15,
                fill_color='blue',fill_alpha=0.5)

plot.add_glyph(source, circle)

# %%
output_file('basicplot.html')
output_notebook()
show(plot)
# Out:
# INFO:bokeh.core.state:Session output file 'basicplot.html' already exists, will be overwritten.
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="74760629-478d-456b-9104-6d4d444e98ae">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="22c080b8-1286-4bed-81ab-7f77059dc981"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
# ...

# %%
from bokeh.io import output_file, show
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
)

map_options = GMapOptions(lat=30.29, lng=-97.73, map_type="roadmap", zoom=11)

plot = GMapPlot(
    x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options
)
plot.title.text = "Austin"

# For GMaps to function, Google requires you obtain and enable an API key:
#
#     https://developers.google.com/maps/documentation/javascript/get-api-key
#
# Replace the value below with your personal API key:
plot.api_key = api_key

source = ColumnDataSource(
    data=dict(
        lat=[30.29, 30.20, 30.29],
        lon=[-97.70, -97.74, -97.78],
    )
)

circle = Circle(x="lon", y="lat", size=15, fill_color="blue", fill_alpha=0.8, line_color=None)
plot.add_glyph(source, circle)

plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
output_file("gmap_plot.html")
show(plot)
# Out:
# INFO:bokeh.core.state:Session output file 'gmap_plot.html' already exists, will be overwritten.
#     <div class="bk-root">
#         <div class="plotdiv" id="dfd538d2-526b-4452-8544-01eb7dd2856d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
# ...

# %%
API_KEY = ''

lat =
long =


src = "https://maps.googleapis.com/maps/api/elevation/json?locations=" + lat + "," + lon + "&key=" + API_KEY
elevator = google.maps.ElevationService
elevator.getElevationForLocations({
          'locations': [location]

# %%
import json

#newfile = pygeoj.new()
newprops = {}

#newfile.define_crs(type="link", link="http://spatialreference.org/ref/epsg/26912/esriwkt/", link_type="esriwkt")
for i, feature in enumerate(testfile):
    newfile.add_feature(properties = newprops,
                    geometry = feature.geometry)
#     print(newfile.all_attributes,
#          newfile.crs)
    

    if i == 5:
        break
#newfile.save('newfile.geojson')

# with open("geotext.txt", "a") as f:
#         f.write(str(json.dumps(newfile[0])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a47e27a9bc38> in <module>()
#       5
#       6 #newfile.define_crs(type="link", link="http://spatialreference.org/ref/epsg/26912/esriwkt/", link_type="esriwkt")
# ----> 7 for i, feature in enumerate(testfile):
#       8     newfile.add_feature(properties = newprops,
#       9                     geometry = feature.geometry)
#
# NameError: name 'testfile' is not defined

# %%
data_simple = {"type": geo['type'],"features":geo.features[0]['geometry']}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-dc5342a64712> in <module>()
# ----> 1 data_simple = {"type": geo['type'],"features":geo.features[0]['geometry']}
#
# AttributeError: 'dict' object has no attribute 'features'

# %%
print(json.dumps(geometry, indent=4))
# Out:
# {
#     "geometry": [
#         {
#             "type": "LineString",
#             "coordinates": [
#                 [
#                     -98.2073199,
#                     29.931372
#                 ],
#                 [
#                     -98.2077049,
#                     29.931369
#                 ],
#                 [
#                     -98.2087179,
#                     29.93138
#                 ],
#                 [
#                     -98.2094179,
#                     29.931381
#                 ],
#                 [
#                     -98.2095799,
#                     29.931381
#                 ],
#                 [
#                     -98.21023789999998,
#                     29.931389
#                 ],
#                 [
#                     -98.2103579,
#                     29.931391
#                 ]
#             ]
#         },
#         {
#             "type": "LineString",
#             "coordinates": [
#                 [
# ...

# %%
from bokeh.io import output_file, show
from bokeh.models import GeoJSONDataSource
from bokeh.plotting import figure
from bokeh.sampledata.sample_geojson import geojson
import json
coords =  {}
with open('austin') as f:
    geo_source = GeoJSONDataSource(geojson=f.read())
#print(geo_source.geojson)
    
# for i, point in enumerate(geo_source.tags):
    
#     print(point)
#     if i == 5:
#         break
    
p = figure()
p.circle(x='x', y='y', alpha=0.9, source=geo_source)
output_file("geolbk.html")
show(p)
# Out:
# INFO:bokeh.core.state:Session output file 'geolbk.html' already exists, will be overwritten.
# ERROR:C:\Users\Kyle's Laptop\Anaconda3\lib\site-packages\bokeh\core\validation\check.py:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: x, y [renderer: GlyphRenderer, ViewModel:GlyphRenderer, ref _id: 31b22028-c924-4426-b51c-9836b701ffb5]
# ERROR:C:\Users\Kyle's Laptop\Anaconda3\lib\site-packages\bokeh\core\validation\check.py:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: x, y [renderer: GlyphRenderer, ViewModel:GlyphRenderer, ref _id: 7e5c3236-bc2f-4503-8308-375b442ad33f]
# WARNING:C:\Users\Kyle's Laptop\Anaconda3\lib\site-packages\bokeh\core\validation\check.py:W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure, ViewModel:Plot, ref _id: 55c05407-b059-4744-a48b-9d4078a6d52a
# ...

# %%
from bokeh.io import output_file, show
from bokeh.models import GeoJSONDataSource, HoverTool
from bokeh.plotting import figure
from bokeh.sampledata.sample_geojson import geojson

p = figure()

p.circle(x='x', y='y', line_color=None, fill_alpha=0.8, size=20,
         source=GeoJSONDataSource(geojson=geojson))

p.add_tools(HoverTool(tooltips=[
    ("Organisation Name", "@OrganisationName")
]))

output_file("geojson_points.html", title="GeoJSON Points")

show(p)
# Out:
# ERROR:C:\Users\Kyle's Laptop\Anaconda3\lib\site-packages\bokeh\core\validation\check.py:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: x, y [renderer: GlyphRenderer, ViewModel:GlyphRenderer, ref _id: 31b22028-c924-4426-b51c-9836b701ffb5]
